# %% [markdown]
# # 06 — Stacking Ensemble
#
# Combine the best classical model, V2 CSP+LDA, and V2 EEGNet via a logistic regression meta-learner trained on val-set predictions.
#
# Evaluates on the held-out test set and compares all V1 + V2 models.

# %%
import subprocess, sys
result = subprocess.run(
    [sys.executable, '../scripts/run_06_ensemble.py'],
    capture_output=False,
)
result.returncode
